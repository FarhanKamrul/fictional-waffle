# %% [markdown]
# # Phase 0: Environment & Workspace Setup
#
# This notebook initializes the workspace directory structure required for the S3 methodology, and optionally tests the library imports to ensure the environment is correctly configured.

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# !pip install diffusers==0.31.0 transformers==4.46.1 accelerate safetensors
# !pip install open-clip-torch pymoo pymc networkx matplotlib scikit-learn pandas datasets
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 100.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 112.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 278.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 128.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 134.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.1/801.1 kB 166.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [accelerate]8 [accelerate]s]ub]
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 84.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 122.7 MB/s  0:00:00
# ...

# %%
import os
import sys

# Define the base workspace directory
WORKSPACE_DIR = os.path.abspath("./workspace")

# Define all required subdirectories based on plan.md
directories = [
    f"{WORKSPACE_DIR}/models/stable-diffusion-2-1",
    f"{WORKSPACE_DIR}/models/stable-diffusion-2-inpainting",
    f"{WORKSPACE_DIR}/models/segformer-b2-clothes",
    f"{WORKSPACE_DIR}/models/clip-vit-large-patch14",
    f"{WORKSPACE_DIR}/models/classifiers/nudenet",
    f"{WORKSPACE_DIR}/models/classifiers/q16",
    f"{WORKSPACE_DIR}/datasets/i2p",
    f"{WORKSPACE_DIR}/datasets/coco/annotations",
    f"{WORKSPACE_DIR}/datasets/coco/val2017",
    f"{WORKSPACE_DIR}/datasets/ring-a-bell",
    f"{WORKSPACE_DIR}/datasets/sae_train_corpus",
    f"{WORKSPACE_DIR}/activations/layer_analysis",
    f"{WORKSPACE_DIR}/activations/attribution_scores",
    f"{WORKSPACE_DIR}/activations/bayesian_traces",
    f"{WORKSPACE_DIR}/generated_images/original",
    f"{WORKSPACE_DIR}/generated_images/baseline_gloce",
    f"{WORKSPACE_DIR}/generated_images/baseline_esd",
    f"{WORKSPACE_DIR}/generated_images/masks",
    f"{WORKSPACE_DIR}/generated_images/s3_alpha_composited",
    f"{WORKSPACE_DIR}/evaluation/unet_pca_maps",
    f"{WORKSPACE_DIR}/evaluation/pareto_fronts",
    f"{WORKSPACE_DIR}/evaluation/entanglement_graphs",
    f"{WORKSPACE_DIR}/code/steerers"
]

# Create directories
for directory in directories:
    os.makedirs(directory, exist_ok=True)

print(f"Successfully initialized {len(directories)} directories under {WORKSPACE_DIR}")
# Out:
# Successfully initialized 23 directories under /home/jovyan/work/fictional-waffle/workspace

# %% [markdown]
# ### Environment Verification
# Run the following cell to verify that all the required libraries (including the new math/optimization tools) are installed.

# %%
try:
    import torch
    import diffusers
    import transformers
    import open_clip
    import pymoo
    import pymc as pm
    import networkx as nx
    import matplotlib
    import sklearn
    import pandas as pd
    print("✅ All core libraries imported successfully!")
    print(f"Torch version: {torch.__version__}")
    print(f"Diffusers version: {diffusers.__version__}")
    print(f"CUDA Available: {torch.cuda.is_available()}")
except ImportError as e:
    print(f"❌ Missing dependency: {e}")
    print("Please ensure you ran the pip install commands from plan.md Step 0.2")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /opt/conda/lib/python3.12/site-packages/arviz/__init__.py:50: FutureWarning:
# ArviZ is undergoing a major refactor to improve flexibility and extensibility while maintaining a user-friendly interface.
# Some upcoming changes may be backward incompatible.
# For details and migration guidance, visit: https://python.arviz.org/en/latest/user_guide/migration_guide.html
#   warn(
# ✅ All core libraries imported successfully!
# Torch version: 2.8.0+cu128
# Diffusers version: 0.31.0
# CUDA Available: True
